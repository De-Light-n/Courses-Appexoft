# %% [markdown]
# # 📝 Домашнє завдання — Алгоритми та структури даних
#
# **До розділу:** уроки [1](lektsiya-1-skladnist-ta-rekursiya.ipynb)–[6](lektsiya-6-paradygmy-algorytmiv.ipynb).
#
# Ці завдання виконуються **прямо в зошиті**: під кожним — порожня комірка, де пишете розв'язок і
# **запускаєте** його (`Shift + Enter`). Намагайтесь спершу продумати складність, а вже потім кодити.
#
# > 💡 Порада: перевіряйте свій код на кількох прикладах (зокрема на «крайніх»: порожній вхід,
# > один елемент, уже відсортовані/повторювані дані).

# %% [markdown]
# ### Завдання 1 — Складність (теорія)
# Для кожного фрагмента визначте складність у нотації Big-O (напишіть відповідь коментарем):
# 1. один цикл `for i in range(n)`;
# 2. два **вкладені** цикли до `n`;
# 3. цикл, у якому `i` щоразу **подвоюється** (`i *= 2`);
# 4. `x in my_list` (список) проти `x in my_set` (множина);
# 5. `my_list.insert(0, x)`.
# _(Урок 1.)_

# %%
# 1) ...
# 2) ...
# 3) ...
# 4) ...
# 5) ...

# %% [markdown]
# ### Завдання 2 — Двійковий пошук
# Реалізуйте функцію `binary_search(arr, target)`, що повертає індекс елемента у
# **відсортованому** масиві або `-1`. Перевірте на кількох прикладах. _(Урок 4.)_

# %%
def binary_search(arr, target):
    ...

# перевірка:
# print(binary_search([1,3,5,7,9], 7))  # 3

# %% [markdown]
# ### Завдання 3 — Розворот зв'язаного списку
# Дано клас `Node` (однобічний список). Напишіть функцію `reverse(head)`, що **розвертає**
# список і повертає нову голову. Складність — O(n), без створення нового списку. _(Урок 2.)_

# %%
class Node:
    def __init__(self, v): self.value = v; self.next = None

def reverse(head):
    ...

# %% [markdown]
# ### Завдання 4 — Черга через два стеки
# Реалізуйте клас `QueueFromStacks` (FIFO) з методами `enqueue(x)` та `dequeue()`,
# використовуючи **лише два списки-стеки** (`append`/`pop`). _(Уроки 2.)_

# %%
class QueueFromStacks:
    def __init__(self):
        self.in_stack = []
        self.out_stack = []
    def enqueue(self, x):
        ...
    def dequeue(self):
        ...

# %% [markdown]
# ### Завдання 5 — Merge sort
# Реалізуйте сортування злиттям `merge_sort(a)` (не використовуючи `sorted`). Поясніть
# коментарем, чому його складність O(n log n). _(Урок 4.)_

# %%
def merge_sort(a):
    ...

# print(merge_sort([5,2,9,1,5,6]))  # [1,2,5,5,6,9]

# %% [markdown]
# ### Завдання 6 — Обхід дерева
# Дано двійкове дерево (клас `TreeNode`). Напишіть **in-order** обхід (рекурсивно **або**
# через стек) і поверніть список значень. _(Урок 3.)_

# %%
class TreeNode:
    def __init__(self, v): self.value=v; self.left=None; self.right=None

def inorder(root):
    ...

# %% [markdown]
# ### Завдання 7 — BFS: найкоротший шлях
# Дано граф (список суміжності, `dict`). Напишіть `shortest_path(graph, start, goal)`, що
# повертає найкоротший шлях (список вершин) у **незваженому** графі або `None`. _(Урок 5.)_

# %%
def shortest_path(graph, start, goal):
    ...

# graph = {'A':['B','C'],'B':['D'],'C':['D'],'D':[]}
# print(shortest_path(graph,'A','D'))

# %% [markdown]
# ### Завдання 8 — DP: сходинки
# Скількома способами піднятись на `n` сходинок, якщо за раз можна крокнути на 1 або 2
# сходинки? Напишіть `climb(n)` через **динамічне програмування** (це замаскований Фібоначчі).
# _(Уроки 1, 6.)_

# %%
def climb(n):
    ...

# print(climb(5))  # 8

# %% [markdown]
# ### Завдання 9 ⭐ — Backtracking: усі підмножини
# Напишіть `subsets(nums)`, що повертає **всі** підмножини списку (power set) через
# backtracking. Порахуйте, скільки їх для списку з `k` елементів (має бути 2^k). _(Урок 6.)_

# %%
def subsets(nums):
    ...

# print(subsets([1,2,3]))  # 8 підмножин

# %% [markdown]
# ---
# ✅ Готово? Збережіть зошит і створіть PR за правилом гілки `<нік>/hw-algo`
# (див. [CONTRIBUTING.md](../CONTRIBUTING.md)). Успіхів! 🚀
