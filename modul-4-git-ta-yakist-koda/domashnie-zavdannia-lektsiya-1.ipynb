# %% [markdown]
# # 📝 Домашнє завдання — Модуль 4, Урок 1 (Git)
#
# **До уроку:** [lektsiya-1-git.ipynb](lektsiya-1-git.ipynb)
#
# Git вивчається **руками в терміналі**, тож ці завдання виконуються не в зошиті, а в консолі.
# Створіть окрему **пісочницю** й виконуйте кроки. Під кожним завданням у code-комірку
# **вставте вивід** відповідної команди (як коментар або трилапковий рядок) — це і буде ваша відповідь.
#
# > 🧪 **Пісочниця (виконайте спершу в терміналі):**
# > ```bash
# > mkdir git-sandbox && cd git-sandbox
# > git init
# > echo "# Мій проєкт" > README.md
# > git add README.md && git commit -m "Initial commit"
# > ```

# %% [markdown]
# ### Завдання 1 — Базовий цикл
# 1. Додайте у `README.md` ще один рядок.
# 2. Подивіться `git status` та `git diff`.
# 3. Зробіть коміт із **гарним** повідомленням.
#
# Вставте нижче вивід `git log --oneline`.

# %%
# Вставте сюди вивід `git log --oneline` (як коментар):

# %% [markdown]
# ### Завдання 2 — Гілки та merge
# 1. Створіть гілку: `git switch -c feature/greeting`.
# 2. Додайте файл `hello.txt`, закомітьте.
# 3. Поверніться на `main` і влийте гілку: `git switch main` → `git merge feature/greeting`.
# 4. Подивіться `git log --oneline --graph --all`.
#
# Вставте нижче граф історії та зазначте: це був **fast-forward** чи merge-коміт? Чому?

# %%
# Вставте сюди `git log --oneline --graph --all` і вашу відповідь:

# %% [markdown]
# ### Завдання 3 — Конфлікт злиття
# 1. У `main` змініть **перший рядок** `README.md` і закомітьте.
# 2. Створіть гілку `feature/title` **від попереднього коміту** й змініть **той самий рядок** інакше, закомітьте.
# 3. Спробуйте злити гілки — виникне **конфлікт**.
# 4. Розв'яжіть його вручну (приберіть маркери `<<<<<<<`, `=======`, `>>>>>>>`), потім `git add` + `git commit`.
#
# Опишіть нижче: як виглядав конфлікт і як ви його розв'язали.

# %%
# Опишіть конфлікт і розв’язання (як коментар):

# %% [markdown]
# ### Завдання 4 — `git stash`
# 1. Внесіть якісь незакомічені зміни у файл.
# 2. Виконайте `git stash` і переконайтесь (`git status`), що робоча копія **чиста**.
# 3. `git stash list`, потім `git stash pop` — поверніть зміни.
#
# Вставте нижче вивід `git stash list` (до `pop`).

# %%
# Вставте сюди вивід `git stash list`:

# %% [markdown]
# ### Завдання 5 — `git cherry-pick`
# 1. У гілці `feature/greeting` зробіть новий коміт (напр. змініть `hello.txt`).
# 2. Перейдіть на `main` і застосуйте **лише цей коміт**: `git cherry-pick <hash>`.
# 3. Подивіться `git log --oneline` — переконайтесь, що з'явилась **копія** коміту.
#
# Вставте нижче хеш вихідного коміту та хеш його копії в `main` — вони різні?

# %%
# Вставте хеші (вихідний і копію) + короткий висновок:

# %% [markdown]
# ### Завдання 6 ⭐ — Інтерактивний rebase (squash) `🚀 Middle+`
# 1. Зробіть **3 маленькі коміти** підряд (напр. `wip 1`, `wip 2`, `wip 3`).
# 2. Об'єднайте їх в **один** через `git rebase -i HEAD~3` (позначте два коміти як `squash`/`s`).
# 3. Задайте фінальному коміту нормальне повідомлення.
#
# Вставте нижче `git log --oneline` до і після — покажіть, що 3 коміти стали 1.

# %%
# Вставте `git log --oneline` ДО і ПІСЛЯ rebase:

# %% [markdown]
# ### Завдання 7 — Теорія (короткі відповіді)
# Дайте **своїми словами** (1–2 речення на кожне), вставивши у комірку нижче:
# 1. Чим `git merge` відрізняється від `git rebase`?
# 2. Чим `git fetch` відрізняється від `git pull`?
# 3. Коли краще `git revert`, а коли `git reset`?
# 4. У чому різниця між **Git** і **GitHub**?

# %%
# 1) ...
# 2) ...
# 3) ...
# 4) ...

# %% [markdown]
# ---
# ### 📤 Як здати
# Створіть гілку за правилом (`<нік>/hw-m4-l1`, див. [CONTRIBUTING.md](../CONTRIBUTING.md)),
# збережіть цей зошит із вашими відповідями та відкрийте **Pull Request**.
